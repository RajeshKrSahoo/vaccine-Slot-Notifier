# %%
'''Getting the input values from Google Spread API'''
import gspread
import pandas as pd

'''Scrapping value from CoWinAPI'''

import pandas as pd
import numpy as np
import requests as rq
from bs4 import BeautifulSoup as bs
import json
import urllib3
urllib3.disable_warnings(urllib3.exceptions.InsecureRequestWarning)
import ssl
ssl._create_default_https_context = ssl._create_unverified_context

'''Twitter Updatation'''
import tweepy
import webbrowser
import time
from tweepy import OAuthHandler

import tweepy
from tweepy import StreamListener
from tweepy import Stream
from datetime import datetime,timedelta
import time
now = datetime.now()
tweet_count=0
base = datetime.today()
print(base)

numdays = 7
date_list = [base + timedelta(days=x) for x in range(numdays)]
# print(date_list)
date_str = [x.strftime("%d-%m-%Y") for x in date_list]

print_flag = 'y'
print_flag = 'y'

##this above import is to minismise SSL Security warning in Macbook


def gspreadData():
    '''Getting the input values from Google Spread API'''
    
    sheet_id='1jYrsjlx4xD8MSkFGM3mItJT59ytoc5_LZJgE6wMSWK0'
    sheet_name='CovidData'
    url = f"https://docs.google.com/spreadsheets/d/{sheet_id}/gviz/tq?tqx=out:csv&sheet={sheet_name}"
    url  
    df=pd.read_csv(url,error_bad_lines=False)
    df.dropna(axis=1, how='all')
    print(df)
    return df



def vaccineSlotsByDist(age,district_id):
    headers={'User-Agent':"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_14_6) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/90.0.4430.93 Safari/537.36"}

    try:
        available_df=[]
        age=age
        
#         'Not Needed above function to use'
#         df_vacc_state=vaccine_state_data()
        try:
#             print(df_vacc_state)
            DIST_ID=district_id
            ##list(df_vacc_state[(df_vacc_state['State_name']== state) & (df_vacc_state['district_name']==district_name)]['district_id'])[0]

        except:
            print("No Combintaiont found")
            return None
            pass

        for inp_date in date_str:
            URL = "https://cdn-api.co-vin.in/api/v2/appointment/sessions/public/calendarByDistrict?district_id={}&date={}".format(DIST_ID, inp_date)
            response = rq.get(URL,headers=headers,verify=False)
            if response.ok:
                resp_json = response.json()
                # print(json.dumps(resp_json, indent = 1))
                if resp_json["centers"]:
#                     print("Available on: {}".format(inp_date))
                    if(print_flag=='y' or print_flag=='Y'):
                        for center in resp_json["centers"]:
                            for session in center["sessions"]:
                                if session["min_age_limit"] <= age :
                                    if(session["vaccine"] != ''):
                                        pass
                                        
                                    else:
                                        
                                        session["vaccine"]='No Information'
#                                     print("\n\n")
                                    available_df.append([center["name"],center["block_name"],center["fee_type"],session["vaccine"],\
                                                        center['district_name'],center['state_name'],\
                                                        
                                                        center['pincode'],inp_date, session["available_capacity"], session["min_age_limit"]
                                                        
                                                        ])
                                                        
                           
                                 

                        
                else:
                    pass
#                     print("No available slots on {}".format(inp_date))




        # Create the pandas DataFrame for re grouping whole data into one particlur data frames
        info_vaccination = pd.DataFrame(available_df, columns = ['Vaccination Center', 'Block_name','Fee_type','Vaccine Type',\
            'District','State Name','Pincode','Available Date','available capacity','Age Group'],index=None)
        
        indexNames = info_vaccination[ (info_vaccination['available capacity'] == 0) ].index
    
        info_vaccination.drop(indexNames , inplace=True)
       
        html=info_vaccination#.set_index(['Available Date', 'State Name','District','pincode'])
        print(html)
        return html

    except Exception as e:
        print("Exception ",e)

def tweet_data(msg):
    '''Twitter Updatation'''


    CONSUMER_KEY='JTZluB3daESewe2ToGofBEdFG'
    CONSUMER_SECRET='hg3BGax9d5TiHw4UmB117WQYKE6Gnhe1dOL0zYyb4DfFlkH5HJ'
    Access_Token='1389917390520033284-of3M07i7EFEtwaM3GtoYkd62vSvaaA'
    Access_Token_Secret='z3ECIPDP6Lh7vbe0k1v0nYxer6GsvCnumsQ3Xtlsr7MqH'


    # callback_uri='oob'
    auth = tweepy.OAuthHandler(CONSUMER_KEY, CONSUMER_SECRET)
    auth.set_access_token(Access_Token,Access_Token_Secret)
    api=tweepy.API(auth)
    
    print(dist)
    try:
        api.update_status("{}".format(msg))
        
        print("TWeet Successful******")
    except Exception as e:
        print("Exception in Tweeter API status Update: ",e)
    
    

    

    
'''Start of the scripts'''
if __name__=='__main__':
    print("hello Starting to schedule the Run!")
    gspread_data=gspreadData()

    for j,i in enumerate(gspread_data['DistId'].tolist()):
        
        
        print(i)
        print("for District Name: ",gspread_data[gspread_data['DistId']==i]['DistName'])
        val_18=vaccineSlotsByDist(40,i)
        time.sleep(2)
        val_45=vaccineSlotsByDist(55,i)
        print(val_45,val_18)
        time.sleep(2)
        try:
            value=pd.concat([val_18, val_45], axis=0)
        except:
            print("Exception in Value concatination")
        print("Value:",value)

        for inp_date in date_str:
            dist='_'.join(gspread_data[gspread_data['DistId']==i]['DistName'].tolist()[0].split(' '))
            
            msg="#{0}\U0001F4E2 \n Date: {1} \n\n\t \U0001F489 Slots Available: \n\t".format(dist,inp_date)
#             print("String dates inserting",dist)
            
            covs_45=len(value[(value['Available Date']==inp_date) & (value['Vaccine Type']=='COVISHIELD') & (value['Age Group']==45)])
           
            covx_45=len(value[(value['Available Date']==inp_date) & (value['Vaccine Type']=='COVAXIN') & (value['Age Group']==45)])
        
            covs_18=len(value[(value['Available Date']==inp_date) & (value['Vaccine Type']=='COVISHIELD') & (value['Age Group']==18)])
           
            covx_18=len(value[(value['Available Date']==inp_date) & (value['Vaccine Type']=='COVAXIN') & (value['Age Group']==18)])
           
                
#             print([covs_45,covx_45,covs_18,covx_18])
            if all(v == 0 for v in [covs_45,covx_45,covs_18,covx_18]):
                print("No data for: ",inp_date)
#                 continue

            else:

                if covs_45 !=0:
                    cov_45_flag='\t Covishield - 45+/{} Slots \n\t'.format(covs_45)
                    msg=msg+cov_45_flag
                if covx_45 !=0:
                    covx_45_flag='\t Covaxin - 45+/{} Slots \n\t'.format(covx_45)
                    msg=msg+covx_45_flag

                if covs_18 !=0:
                    covs_18_flag='\t Covishield (18-44)/{} Slots \n\t'.format(covs_18)
                    msg=msg + covs_18_flag

                if covx_18 !=0:
                    covx_18_flag='\t Covaxin (18-44)/{} Slots \n\t'.format(covx_18)
                    msg=msg+ covx_18_flag

                msg=msg+'#COVID19IndiaHelp #VaxTrack \n\n Last Tracked: {}'.format(now.strftime('%d-%m-%Y, %I:%M%p'))
                print(msg)
                tweet_data(msg)
                time.sleep(1.5)
                tweet_count+=1
        if j%2==0:
            print("Waiting time ^_^")
            time.sleep(150)
            print("Waiting time ENDS ^_^")
        else:
            pass
                

print("Total Tweet done in this Schdule: ",tweet_count)
# Out:
# 2021-05-14 15:58:04.341938
# hello Starting to schedule the Run!
#     DistId        DistName  Unnamed: 2  Unnamed: 3  Unnamed: 4  Unnamed: 5  \
# 0      457         Cuttack         NaN         NaN         NaN         NaN
# 1      446          Khurda         NaN         NaN         NaN         NaN
# 2      454         Bhadrak         NaN         NaN         NaN         NaN
# 3      447        Balesore         NaN         NaN         NaN         NaN
# 4      453      Sundargarh         NaN         NaN         NaN         NaN
# 5      581       Hyderabad         NaN         NaN         NaN         NaN
# 6       78           Arwal         NaN         NaN         NaN         NaN
# 7      460          Jajpur         NaN         NaN         NaN         NaN
# 8       92          Nawada         NaN         NaN         NaN         NaN
# 9      445           Angul         NaN         NaN         NaN         NaN
# 10     737   West Bardhman         NaN         NaN         NaN         NaN
# 11     247  East Singhbhum         NaN         NaN         NaN         NaN
# 12     456      Mayurbhanj         NaN         NaN         NaN         NaN
#
#     Unnamed: 6  Unnamed: 7  Unnamed: 8  Unnamed: 9  ...  Unnamed: 16  \
# 0          NaN         NaN         NaN         NaN  ...          NaN
# 1          NaN         NaN         NaN         NaN  ...          NaN
# 2          NaN         NaN         NaN         NaN  ...          NaN
# 3          NaN         NaN         NaN         NaN  ...          NaN
# 4          NaN         NaN         NaN         NaN  ...          NaN
# 5          NaN         NaN         NaN         NaN  ...          NaN
# 6          NaN         NaN         NaN         NaN  ...          NaN
# 7          NaN         NaN         NaN         NaN  ...          NaN
# 8          NaN         NaN         NaN         NaN  ...          NaN
# 9          NaN         NaN         NaN         NaN  ...          NaN
# 10         NaN         NaN         NaN         NaN  ...          NaN
# 11         NaN         NaN         NaN         NaN  ...          NaN
# 12         NaN         NaN         NaN         NaN  ...          NaN
#
#     Unnamed: 17  Unnamed: 18  Unnamed: 19  Unnamed: 20  Unnamed: 21  \
# 0           NaN          NaN          NaN          NaN          NaN
# 1           NaN          NaN          NaN          NaN          NaN
# 2           NaN          NaN          NaN          NaN          NaN
# 3           NaN          NaN          NaN          NaN          NaN
# 4           NaN          NaN          NaN          NaN          NaN
# 5           NaN          NaN          NaN          NaN          NaN
# 6           NaN          NaN          NaN          NaN          NaN
# 7           NaN          NaN          NaN          NaN          NaN
# 8           NaN          NaN          NaN          NaN          NaN
# 9           NaN          NaN          NaN          NaN          NaN
# 10          NaN          NaN          NaN          NaN          NaN
# 11          NaN          NaN          NaN          NaN          NaN
# 12          NaN          NaN          NaN          NaN          NaN
#
#     Unnamed: 22  Unnamed: 23  Unnamed: 24  Unnamed: 25
# 0           NaN          NaN          NaN          NaN
# 1           NaN          NaN          NaN          NaN
# 2           NaN          NaN          NaN          NaN
# 3           NaN          NaN          NaN          NaN
# 4           NaN          NaN          NaN          NaN
# 5           NaN          NaN          NaN          NaN
# 6           NaN          NaN          NaN          NaN
# 7           NaN          NaN          NaN          NaN
# 8           NaN          NaN          NaN          NaN
# 9           NaN          NaN          NaN          NaN
# 10          NaN          NaN          NaN          NaN
# 11          NaN          NaN          NaN          NaN
# 12          NaN          NaN          NaN          NaN
#
# [13 rows x 26 columns]
# 457
# for District Name:  0    Cuttack
# Name: DistName, dtype: object
# Empty DataFrame
# Columns: [Vaccination Center, Block_name, Fee_type, Vaccine Type, District, State Name, Pincode, Available Date, available capacity, Age Group]
# Index: []
# Empty DataFrame
# Columns: [Vaccination Center, Block_name, Fee_type, Vaccine Type, District, State Name, Pincode, Available Date, available capacity, Age Group]
# Index: []
# Empty DataFrame
# Columns: [Vaccination Center, Block_name, Fee_type, Vaccine Type, District, State Name, Pincode, Available Date, available capacity, Age Group]
# Index: [] Empty DataFrame
# Columns: [Vaccination Center, Block_name, Fee_type, Vaccine Type, District, State Name, Pincode, Available Date, available capacity, Age Group]
# Index: []
# Value: Empty DataFrame
# Columns: [Vaccination Center, Block_name, Fee_type, Vaccine Type, District, State Name, Pincode, Available Date, available capacity, Age Group]
# Index: []
# No data for:  14-05-2021
# No data for:  15-05-2021
# No data for:  16-05-2021
# No data for:  17-05-2021
# No data for:  18-05-2021
# No data for:  19-05-2021
# No data for:  20-05-2021
# 446
# for District Name:  1    Khurda
# Name: DistName, dtype: object
# Empty DataFrame
# Columns: [Vaccination Center, Block_name, Fee_type, Vaccine Type, District, State Name, Pincode, Available Date, available capacity, Age Group]
# Index: []
# Empty DataFrame
# Columns: [Vaccination Center, Block_name, Fee_type, Vaccine Type, District, State Name, Pincode, Available Date, available capacity, Age Group]
# Index: []
# Empty DataFrame
# Columns: [Vaccination Center, Block_name, Fee_type, Vaccine Type, District, State Name, Pincode, Available Date, available capacity, Age Group]
# Index: [] Empty DataFrame
# Columns: [Vaccination Center, Block_name, Fee_type, Vaccine Type, District, State Name, Pincode, Available Date, available capacity, Age Group]
# Index: []
# Value: Empty DataFrame
# Columns: [Vaccination Center, Block_name, Fee_type, Vaccine Type, District, State Name, Pincode, Available Date, available capacity, Age Group]
# Index: []
# No data for:  14-05-2021
# No data for:  15-05-2021
# No data for:  16-05-2021
# No data for:  17-05-2021
# No data for:  18-05-2021
# No data for:  19-05-2021
# No data for:  20-05-2021
# 454
# for District Name:  2    Bhadrak
# Name: DistName, dtype: object
# Empty DataFrame
# Columns: [Vaccination Center, Block_name, Fee_type, Vaccine Type, District, State Name, Pincode, Available Date, available capacity, Age Group]
# Index: []
# Empty DataFrame
# Columns: [Vaccination Center, Block_name, Fee_type, Vaccine Type, District, State Name, Pincode, Available Date, available capacity, Age Group]
# Index: []
# Empty DataFrame
# Columns: [Vaccination Center, Block_name, Fee_type, Vaccine Type, District, State Name, Pincode, Available Date, available capacity, Age Group]
# Index: [] Empty DataFrame
# Columns: [Vaccination Center, Block_name, Fee_type, Vaccine Type, District, State Name, Pincode, Available Date, available capacity, Age Group]
# Index: []
# Value: Empty DataFrame
# Columns: [Vaccination Center, Block_name, Fee_type, Vaccine Type, District, State Name, Pincode, Available Date, available capacity, Age Group]
# Index: []
# No data for:  14-05-2021
# No data for:  15-05-2021
# No data for:  16-05-2021
# No data for:  17-05-2021
# No data for:  18-05-2021
# No data for:  19-05-2021
# No data for:  20-05-2021
# 447
# for District Name:  3    Balesore
# Name: DistName, dtype: object
# Empty DataFrame
# Columns: [Vaccination Center, Block_name, Fee_type, Vaccine Type, District, State Name, Pincode, Available Date, available capacity, Age Group]
# Index: []
# Empty DataFrame
# Columns: [Vaccination Center, Block_name, Fee_type, Vaccine Type, District, State Name, Pincode, Available Date, available capacity, Age Group]
# Index: []
# Empty DataFrame
# Columns: [Vaccination Center, Block_name, Fee_type, Vaccine Type, District, State Name, Pincode, Available Date, available capacity, Age Group]
# Index: [] Empty DataFrame
# Columns: [Vaccination Center, Block_name, Fee_type, Vaccine Type, District, State Name, Pincode, Available Date, available capacity, Age Group]
# Index: []
# Value: Empty DataFrame
# Columns: [Vaccination Center, Block_name, Fee_type, Vaccine Type, District, State Name, Pincode, Available Date, available capacity, Age Group]
# Index: []
# No data for:  14-05-2021
# No data for:  15-05-2021
# No data for:  16-05-2021
# No data for:  17-05-2021
# No data for:  18-05-2021
# No data for:  19-05-2021
# No data for:  20-05-2021
# 453
# for District Name:  4    Sundargarh
# Name: DistName, dtype: object
# Empty DataFrame
# Columns: [Vaccination Center, Block_name, Fee_type, Vaccine Type, District, State Name, Pincode, Available Date, available capacity, Age Group]
# Index: []
# Empty DataFrame
# Columns: [Vaccination Center, Block_name, Fee_type, Vaccine Type, District, State Name, Pincode, Available Date, available capacity, Age Group]
# Index: []
# Empty DataFrame
# Columns: [Vaccination Center, Block_name, Fee_type, Vaccine Type, District, State Name, Pincode, Available Date, available capacity, Age Group]
# Index: [] Empty DataFrame
# Columns: [Vaccination Center, Block_name, Fee_type, Vaccine Type, District, State Name, Pincode, Available Date, available capacity, Age Group]
# Index: []
# Value: Empty DataFrame
# Columns: [Vaccination Center, Block_name, Fee_type, Vaccine Type, District, State Name, Pincode, Available Date, available capacity, Age Group]
# Index: []
# No data for:  14-05-2021
# No data for:  15-05-2021
# No data for:  16-05-2021
# No data for:  17-05-2021
# No data for:  18-05-2021
# No data for:  19-05-2021
# No data for:  20-05-2021
# 581
# for District Name:  5    Hyderabad
# Name: DistName, dtype: object
# Empty DataFrame
# Columns: [Vaccination Center, Block_name, Fee_type, Vaccine Type, District, State Name, Pincode, Available Date, available capacity, Age Group]
# Index: []
# Empty DataFrame
# Columns: [Vaccination Center, Block_name, Fee_type, Vaccine Type, District, State Name, Pincode, Available Date, available capacity, Age Group]
# Index: []
# Empty DataFrame
# Columns: [Vaccination Center, Block_name, Fee_type, Vaccine Type, District, State Name, Pincode, Available Date, available capacity, Age Group]
# Index: [] Empty DataFrame
# Columns: [Vaccination Center, Block_name, Fee_type, Vaccine Type, District, State Name, Pincode, Available Date, available capacity, Age Group]
# Index: []
# Value: Empty DataFrame
# Columns: [Vaccination Center, Block_name, Fee_type, Vaccine Type, District, State Name, Pincode, Available Date, available capacity, Age Group]
# Index: []
# No data for:  14-05-2021
# No data for:  15-05-2021
# No data for:  16-05-2021
# No data for:  17-05-2021
# No data for:  18-05-2021
# No data for:  19-05-2021
# No data for:  20-05-2021
# 78
# for District Name:  6    Arwal
# Name: DistName, dtype: object
#                 Vaccination Center                Block_name Fee_type  \
# 0   Middle School Sonbhadra-18 Yrs  Sonbhadra Bansi Suryapur     Free
# 1   Middle School Sonbhadra-18 Yrs  Sonbhadra Bansi Suryapur     Free
# 3      High School Karpi- 18 Years                     Karpi     Free
# 5    Old PHC Wasilpur-Arwal 18 Yrs                     Arwal     Free
# 9   Model High School Kaler-18 Yrs                     Kaler     Free
# 10   Middle School Kurtha - 18 Yrs                    Kurtha     Free
# 11  Middle School Sonbhadra-18 Yrs  Sonbhadra Bansi Suryapur     Free
# 13   Middle School Kurtha - 18 Yrs                    Kurtha     Free
#
#    Vaccine Type District State Name  Pincode Available Date  \
# 0    COVISHIELD    Arwal      Bihar   804419     14-05-2021
# 1    COVISHIELD    Arwal      Bihar   804419     14-05-2021
# 3    COVISHIELD    Arwal      Bihar   804419     14-05-2021
# 5    COVISHIELD    Arwal      Bihar   804401     14-05-2021
# 9    COVISHIELD    Arwal      Bihar   824127     14-05-2021
# 10   COVISHIELD    Arwal      Bihar   804421     14-05-2021
# 11   COVISHIELD    Arwal      Bihar   804419     15-05-2021
# 13   COVISHIELD    Arwal      Bihar   804421     15-05-2021
#
#     available capacity  Age Group
# 0                    1         18
# 1                   74         18
# 3                  137         18
# 5                  141         18
# 9                  141         18
# 10                 131         18
# 11                  75         18
# 13                 150         18
#                 Vaccination Center                Block_name Fee_type  \
# 0   Middle School Sonbhadra-18 Yrs  Sonbhadra Bansi Suryapur     Free
# 1   Middle School Sonbhadra-18 Yrs  Sonbhadra Bansi Suryapur     Free
# 2                        Karpi PHC                     Karpi     Free
# 3                        Karpi PHC                     Karpi     Free
# 4          Old Building -PHC Kaler                     Kaler     Free
# 5          Middle School Sonbhadra  Sonbhadra Bansi Suryapur     Free
# 7      High School Karpi- 18 Years                     Karpi     Free
# 9    Old PHC Wasilpur-Arwal 18 Yrs                     Arwal     Free
# 10                     APHC Jaypur                     Kaler     Free
# 12       Red Cross Building- Arwal                     Arwal     Free
# 13       Red Cross Building- Arwal                     Arwal     Free
# 15             Arwal PHC- Wasilpur                     Arwal     Free
# 17  Model High School Kaler-18 Yrs                     Kaler     Free
# 18                   APHC Khatangi  Sonbhadra Bansi Suryapur     Free
# 19   Middle School Kurtha - 18 Yrs                    Kurtha     Free
# 20  Middle School Sonbhadra-18 Yrs  Sonbhadra Bansi Suryapur     Free
# 21                   APHC Khatangi  Sonbhadra Bansi Suryapur     Free
# 22         Arwal Sadar Hospital DH                     Arwal     Free
# 24   Middle School Kurtha - 18 Yrs                    Kurtha     Free
#
05-2021
#
# 	 💉 Slots Available:
# 		 Covishield - 45+/3 Slots
# 		 Covishield (18-44)/4 Slots
# 	#COVID19IndiaHelp #VaxTrack
#
#  Last Tracked: 14-05-2021, 03:58PM
# Arwal
# TWeet Successful******
# No data for:  16-05-2021
# No data for:  17-05-2021
# No data for:  18-05-2021
# No data for:  19-05-2021
# No data for:  20-05-2021
# 460
# for District Name:  7    Jajpur
# Name: DistName, dtype: object
# Empty DataFrame
# Columns: [Vaccination Center, Block_name, Fee_type, Vaccine Type, District, State Name, Pincode, Available Date, available capacity, Age Group]
# Index: []
# Empty DataFrame
# Columns: [Vaccination Center, Block_name, Fee_type, Vaccine Type, District, State Name, Pincode, Available Date, available capacity, Age Group]
# Index: []
# Empty DataFrame
# Columns: [Vaccination Center, Block_name, Fee_type, Vaccine Type, District, State Name, Pincode, Available Date, available capacity, Age Group]
# Index: [] Empty DataFrame
# Columns: [Vaccination Center, Block_name, Fee_type, Vaccine Type, District, State Name, Pincode, Available Date, available capacity, Age Group]
# Index: []
# Value: Empty DataFrame
# Columns: [Vaccination Center, Block_name, Fee_type, Vaccine Type, District, State Name, Pincode, Available Date, available capacity, Age Group]
# Index: []
# No data for:  14-05-2021
# No data for:  15-05-2021
# No data for:  16-05-2021
# No data for:  17-05-2021
# No data for:  18-05-2021
# No data for:  19-05-2021
# No data for:  20-05-2021
# 92
# for District Name:  8    Nawada
# Name: DistName, dtype: object
#    Vaccination Center Block_name Fee_type Vaccine Type District State Name  \
# 11      A MESKAUR PHC    Meskaur     Free      COVAXIN   Nawada      Bihar
# 82      A MESKAUR PHC    Meskaur     Free      COVAXIN   Nawada      Bihar
# 92      A MESKAUR PHC    Meskaur     Free      COVAXIN   Nawada      Bihar
#
#     Pincode Available Date  available capacity  Age Group
# 11   805129     14-05-2021                 100         18
# 82   805129     15-05-2021                 100         18
# 92   805129     16-05-2021                 100         18
#      Vaccination Center    Block_name Fee_type Vaccine Type District  \
# 1      UPHC ANSAR NAGAR  Nawada Sadar     Free   COVISHIELD   Nawada
# 4           HSC Pakaria     Nardiganj     Free   COVISHIELD   Nawada
# 5           HSC Pakaria     Nardiganj     Free   COVISHIELD   Nawada
# 6           HSC Pakaria     Nardiganj     Free   COVISHIELD   Nawada
# 7           HSC Pakaria     Nardiganj     Free   COVISHIELD   Nawada
# ...                 ...           ...      ...          ...      ...
# 4093      A RAJAULI PHC       Rajauli     Free   COVISHIELD   Nawada
# 4094      A RAJAULI PHC       Rajauli     Free   COVISHIELD   Nawada
# 4095      A RAJAULI PHC       Rajauli     Free   COVISHIELD   Nawada
# 4096      A RAJAULI PHC       Rajauli     Free   COVISHIELD   Nawada
# 4097      A RAJAULI PHC       Rajauli     Free   COVISHIELD   Nawada
#
#      State Name  Pincode Available Date  available capacity  Age Group
# 1         Bihar   805110     14-05-2021                 242         45
# 4         Bihar   805109     14-05-2021                 123         45
# 5         Bihar   805109     14-05-2021                 125         45
# 6         Bihar   805109     14-05-2021                 125         45
# 7         Bihar   805109     14-05-2021                 125         45
# ...         ...      ...            ...                 ...        ...
# 4093      Bihar   805125     20-05-2021                 125         45
# 4094      Bihar   805125     20-05-2021                 124         45
# 4095      Bihar   805125     20-05-2021                 124         45
# 4096      Bihar   805125     20-05-2021                 125         45
# 4097      Bihar   805125     20-05-2021                 124         45
#
# [3999 rows x 10 columns]
#      Vaccination Center    Block_name Fee_type Vaccine Type District  \
# 1      UPHC ANSAR NAGAR  Nawada Sadar     Free   COVISHIELD   Nawada
# 4           HSC Pakaria     Nardiganj     Free   COVISHIELD   Nawada
# 5           HSC Pakaria     Nardiganj     Free   COVISHIELD   Nawada
# 6           HSC Pakaria     Nardiganj     Free   COVISHIELD   Nawada
# 7           HSC Pakaria     Nardiganj     Free   COVISHIELD   Nawada
# ...                 ...           ...      ...          ...      ...
# 4093      A RAJAULI PHC       Rajauli     Free   COVISHIELD   Nawada
# 4094      A RAJAULI PHC       Rajauli     Free   COVISHIELD   Nawada
# 4095      A RAJAULI PHC       Rajauli     Free   COVISHIELD   Nawada
# 4096      A RAJAULI PHC       Rajauli     Free   COVISHIELD   Nawada
# 4097      A RAJAULI PHC       Rajauli     Free   COVISHIELD   Nawada
#
#      State Name  Pincode Available Date  available capacity  Age Group
# 1         Bihar   805110     14-05-2021                 242         45
# 4         Bihar   805109     14-05-2021                 123         45
# 5         Bihar   805109     14-05-2021                 125         45
# 6         Bihar   805109     14-05-2021                 125         45
# 7         Bihar   805109     14-05-2021                 125         45
# ...         ...      ...            ...                 ...        ...
# 4093      Bihar   805125     20-05-2021                 125         45
# 4094      Bihar   805125     20-05-2021                 124         45
# 4095      Bihar   805125     20-05-2021                 124         45
# 4096      Bihar   805125     20-05-2021                 125         45
# 4097      Bihar   805125     20-05-2021                 124         45
#
# [3999 rows x 10 columns]    Vaccination Center Block_name Fee_type Vaccine Type District State Name  \
# 11      A MESKAUR PHC    Meskaur     Free      COVAXIN   Nawada      Bihar
# 82      A MESKAUR PHC    Meskaur     Free      COVAXIN   Nawada      Bihar
# 92      A MESKAUR PHC    Meskaur     Free      COVAXIN   Nawada      Bihar
#
#     Pincode Available Date  available capacity  Age Group
# 11   805129     14-05-2021                 100         18
# 82   805129     15-05-2021                 100         18
# 92   805129     16-05-2021                 100         18
# Value:      Vaccination Center    Block_name Fee_type Vaccine Type District  \
# 11        A MESKAUR PHC       Meskaur     Free      COVAXIN   Nawada
# 82        A MESKAUR PHC       Meskaur     Free      COVAXIN   Nawada
# 92        A MESKAUR PHC       Meskaur     Free      COVAXIN   Nawada
# 1      UPHC ANSAR NAGAR  Nawada Sadar     Free   COVISHIELD   Nawada
# 4           HSC Pakaria     Nardiganj     Free   COVISHIELD   Nawada
# ...                 ...           ...      ...          ...      ...
# 4093      A RAJAULI PHC       Rajauli     Free   COVISHIELD   Nawada
# 
# 27  Tata Motors Hos. Telco Govt  Jugalsalai Sah Golmu     Free      COVAXIN
# 44      TMH Bistupur Government  Jugalsalai Sah Golmu     Free      COVAXIN
#
#           District State Name  Pincode Available Date  available capacity  \
# 0   East Singhbhum  Jharkhand   831003     14-05-2021                  53
# 1   East Singhbhum  Jharkhand   831003     14-05-2021                 102
# 26  East Singhbhum  Jharkhand   831017     14-05-2021                   8
# 27  East Singhbhum  Jharkhand   831017     14-05-2021                  31
# 44  East Singhbhum  Jharkhand   831001     14-05-2021                   1
#
#     Age Group
# 0          45
# 1          45
# 26         45
# 27         45
# 44         45   Empty DataFrame
# Columns: [Vaccination Center, Block_name, Fee_type, Vaccine Type, District, State Name, Pincode, Available Date, available capacity, Age Group]
# Index: []
# Value:              Vaccination Center            Block_name Fee_type Vaccine Type  \
# 0   Tinplate Hos. Golmuri Govt.  Jugalsalai Sah Golmu     Free   COVISHIELD
# 1   Tinplate Hos. Golmuri Govt.  Jugalsalai Sah Golmu     Free      COVAXIN
# 26  Tata Motors Hos. Telco Govt  Jugalsalai Sah Golmu     Free   COVISHIELD
# 27  Tata Motors Hos. Telco Govt  Jugalsalai Sah Golmu     Free      COVAXIN
# 44      TMH Bistupur Government  Jugalsalai Sah Golmu     Free      COVAXIN
#
#           District State Name  Pincode Available Date  available capacity  \
# 0   East Singhbhum  Jharkhand   831003     14-05-2021                  53
# 1   East Singhbhum  Jharkhand   831003     14-05-2021                 102
# 26  East Singhbhum  Jharkhand   831017     14-05-2021                   8
# 27  East Singhbhum  Jharkhand   831017     14-05-2021                  31
# 44  East Singhbhum  Jharkhand   831001     14-05-2021                   1
#
#     Age Group
# 0          45
# 1          45
# 26         45
# 27         45
# 44         45
# #East_Singhbhum📢
#  Date: 14-05-2021
#
# 	 💉 Slots Available:
# 		 Covishield - 45+/2 Slots
# 		 Covaxin - 45+/3 Slots
# 	#COVID19IndiaHelp #VaxTrack
#
#  Last Tracked: 14-05-2021, 03:58PM
# East_Singhbhum
# TWeet Successful******
# No data for:  15-05-2021
# No data for:  16-05-2021
# No data for:  17-05-2021
# No data for:  18-05-2021
# No data for:  19-05-2021
# No data for:  20-05-2021
# 456
# for District Name:  12    Mayurbhanj
# Name: DistName, dtype: object
# Empty DataFrame
# Columns: [Vaccination Center, Block_name, Fee_type, Vaccine Type, District, State Name, Pincode, Available Date, available capacity, Age Group]
# Index: []
#   Vaccination Center Block_name Fee_type Vaccine Type    District State Name  \
# 2       PPC Karanjia   Karanjia     Free   COVISHIELD  Mayurbhanj     Odisha
#
#    Pincode Available Date  available capacity  Age Group
# 2   757037     14-05-2021                  35         45
#   Vaccination Center Block_name Fee_type Vaccine Type    District State Name  \
# 2       PPC Karanjia   Karanjia     Free   COVISHIELD  Mayurbhanj     Odisha
#
#    Pincode Available Date  available capacity  Age Group
# 2   757037     14-05-2021                  35         45   Empty DataFrame
# Columns: [Vaccination Center, Block_name, Fee_type, Vaccine Type, District, State Name, Pincode, Available Date, available capacity, Age Group]
# Index: []
# Value:   Vaccination Center Block_name Fee_type Vaccine Type    District State Name  \
# 2       PPC Karanjia   Karanjia     Free   COVISHIELD  Mayurbhanj     Odisha
#
#   Pincode Available Date available capacity Age Group
# 2  757037     14-05-2021                 35        45
# #Mayurbhanj📢
#  Date: 14-05-2021
#
# 	 💉 Slots Available:
# 		 Covishield - 45+/1 Slots
# 	#COVID19IndiaHelp #VaxTrack
#
#  Last Tracked: 14-05-2021, 03:58PM
# Mayurbhanj
# TWeet Successful******
# No data for:  15-05-2021
# No data for:  16-05-2021
# No data for:  17-05-2021
# No data for:  18-05-2021
# No data for:  19-05-2021
# No data for:  20-05-2021
# Total Tweet done in this Schdule:  11
